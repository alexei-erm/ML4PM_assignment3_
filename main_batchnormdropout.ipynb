# %%
from model import *
from utils import *
from training import *
from data_processing import *

import importlib
import imports
importlib.reload(imports)

device = 'mps'
model_name = 'batchnormdropout'

# Enable autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
folder = os.getcwd()
filename = f'{folder}/ncmapps_ds02.csv'
print(filename)
# Out:
# /Users/alexei.ermochkine/Desktop/ma5/ML4PM/assignment_3_graded/ML4PM_assignment3/ncmapps_ds02.csv

# %%
df = pd.read_csv(filename)
df.head()
# Out:
#          T24        T30        T48        T50        P15         P2  \
# 0  593.28656  1422.0460  1797.2323  1214.0819  15.626362  11.445379
# 1  593.30220  1422.3720  1797.9927  1214.1847  15.607640  11.424822
# 2  593.14215  1421.8730  1797.1808  1213.5430  15.581609  11.407368
# 3  592.98883  1421.4746  1796.5925  1213.0120  15.554759  11.387945
# 4  592.66296  1420.8185  1795.7623  1212.4274  15.512026  11.356153
#
#          P21        P24       Ps30        P40  ...        Wf        alt  \
# 0  15.864327  19.897537  327.51962  332.79700  ...  3.811431   9889.289
# 1  15.845321  19.881628  327.48330  332.75565  ...  3.812693   9951.729
# 2  15.818893  19.848164  326.81784  332.08163  ...  3.803472  10011.879
# 3  15.791634  19.814800  326.22076  331.47592  ...  3.795554  10073.271
# 4  15.748249  19.760134  325.36660  330.60760  ...  3.784542  10136.359
#
#        Mach        TRA         T2  RUL  Fc  unit  hs  cycle
# 0  0.443401  76.022545  496.67758   74   3     2   1      1
# 1  0.444472  76.222015  496.53890   74   3     2   1      1
# 2  0.445830  76.191210  496.43396   74   3     2   1      1
# 3  0.446986  76.196846  496.30667   74   3     2   1      1
# 4  0.446471  76.204480  496.02774   74   3     2   1      1
#
# [5 rows x 23 columns]

# %%
LABELS = ['RUL']

# %% [markdown]
# Operative Conditions ($w$)
#
# DASHlink- Flight Data For Tail 687.(2012). Retrieved on 2019-01-29 from https://c3.nasa.gov/dashlink/

# %%
W_VAR = ['alt', 'Mach', 'TRA', 'T2']

# %% [markdown]
# Sensor readings ($X_s$)

# %%
XS_VAR = ['T24', 'T30', 'T48', 'T50', 'P15', 'P2', 'P21', 'P24', 'Ps30', 'P40', 'P50', 'Nf', 'Nc', 'Wf']

# %%
# dataset parameters
TRAIN_UNITS = [2, 5, 10, 16, 18, 20]
TEST_UNITS = [11, 14, 15]

DEFAULT_PARAMS = {
    # CNN model parameters
    'in_channels': 18, 
    'out_channels': 1,
    'window': 50, 
    'n_ch': 10, 
    'n_k': 10, 
    'n_hidden': 50, 
    'n_layers': 3,
    'dropout': 0.1,
    'padding': 'same',
    'use_batchnorm': True,
    # training parameters
    'batch_size': 256,  
    'base_lr': 1e-3,
    'weight_decay': 1e-5,
    'max_epochs': 50
}


DATASETS = create_datasets(df, window_size=DEFAULT_PARAMS['window'], train_units=TRAIN_UNITS, test_units=TEST_UNITS)
LOADERS = create_data_loaders(DATASETS, batch_size=DEFAULT_PARAMS['batch_size'], val_split=0.2)
# Out:
# train_size: 403236	validation_size: 100809	test_size: 115274

# %%
def run_single(seed, params=DEFAULT_PARAMS):
    seed_everything(seed)

    model = CNN(
        in_channels=params['in_channels'],
        out_channels=params['out_channels'], 
        n_ch=params['n_ch'],
        n_k=params['n_k'],
        n_hidden=params['n_hidden'],
        n_layers=params['n_layers'],
        dropout=params['dropout'],
        padding=params['padding'],
        use_batchnorm=params['use_batchnorm']
    ).to(device)  # Move model to device immediately after creation

    print(model)

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=params['base_lr'],
        weight_decay=params['weight_decay'],
    )

    criterion = nn.MSELoss()
    trainer = Trainer(
        model,
        optimizer,
        criterion=criterion,
        n_epochs=params['max_epochs'],
        seed=seed,
        device=device,  # Pass device to trainer
        model_name=model_name
    )

    trainer.fit(LOADERS)
    df_eval, df_eval_out = trainer.eval_rul_prediction(LOADERS[1])
    df_test, df_test_out = trainer.eval_rul_prediction(LOADERS[2])
    return df_eval, df_eval_out, df_test, df_test_out, trainer.losses4aggregation

# %% [markdown]
# ## TRAINING ON 5 SEEDS
# ## reminder: CHANGE FOLDER AND MODEL_NAME IN TRAINING.PY BEFORE RUNNING !!!!!

# %%
SEED = 42
seed_everything(SEED)
device = 'mps'
N_RUNS = 5

df_list = []  
all_df_test = []
all_train_losses = []
all_eval_losses = []
all_test_losses = []

for seed in range(SEED, SEED+N_RUNS):
    print("--------------------- BEGGINING NEW SEED:", seed, "----------------")
    df_eval, df_eval_out, df_test, df_test_out, losses4aggregation = run_single(seed)
    all_train_losses.append(losses4aggregation['train'])
    all_eval_losses.append(losses4aggregation['eval'])
    all_test_losses.append(losses4aggregation['test'])
    all_df_test.append(df_test)
    df_list.append(df_test_out)  

df_all = pd.concat(df_list, ignore_index=True)  
all_train_losses = np.array(all_train_losses)
all_eval_losses = np.array(all_eval_losses)
all_test_losses = np.array(all_test_losses)
# Out:
# --------------------- BEGGINING NEW SEED: 42 ----------------
# CNN(
#   (conv_layers): Sequential(
#     (0): Conv1d(18, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (7): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=500, out_features=50, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (bn_fc): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=50, out_features=1, bias=True)
# )
# Training model for 50 epochs...
# /Users/alexei.ermochkine/Desktop/ma5/ML4PM/venv4ml4pm/lib/python3.12/site-packages/torch/nn/modules/conv.py:304: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1032.)
#   return F.conv1d(input, weight, bias, self.stride,
# [Epoch 1] train_loss = 149.71219, eval_loss = 93.91817, test_loss = 226.27605 [24.7s]
# [Epoch 2] train_loss = 57.89343, eval_loss = 106.58376, test_loss = 83.60838 [24.1s]
# [Epoch 3] train_loss = 53.58436, eval_loss = 46.98509, test_loss = 68.97427 [24.9s]
# [Epoch 4] train_loss = 52.17458, eval_loss = 289.12057, test_loss = 260.28735 [24.5s]
# [Epoch 5] train_loss = 49.66523, eval_loss = 130.58122, test_loss = 98.04920 [23.0s]
# [Epoch 6] train_loss = 48.57662, eval_loss = 227.85365, test_loss = 518.70123 [22.0s]
# [Epoch 7] train_loss = 47.82404, eval_loss = 115.40887, test_loss = 312.58295 [22.0s]
# [Epoch 8] train_loss = 46.93541, eval_loss = 197.00426, test_loss = 117.49368 [22.0s]
# [Epoch 39] train_loss = 39.05511, eval_loss = 113.64202, test_loss = 109.22556 [26.3s]
# [Epoch 40] train_loss = 39.13434, eval_loss = 189.71046, test_loss = 168.25560 [24.8s]
# [Epoch 41] train_loss = 38.80421, eval_loss = 115.18570, test_loss = 140.98468 [24.6s]
# [Epoch 42] train_loss = 38.61525, eval_loss = 154.95168, test_loss = 135.25397 [23.7s]
# [Epoch 43] train_loss = 38.59370, eval_loss = 175.12724, test_loss = 147.15698 [25.8s]
# [Epoch 44] train_loss = 38.94122, eval_loss = 66.98076, test_loss = 55.54682 [24.0s]
# [Epoch 45] train_loss = 38.63822, eval_loss = 42.71610, test_loss = 126.57978 [24.7s]
# [Epoch 46] train_loss = 38.31273, eval_loss = 174.53935, test_loss = 235.75655 [24.5s]
# [Epoch 47] train_loss = 38.51741, eval_loss = 124.65201, test_loss = 172.36499 [23.2s]
# [Epoch 48] train_loss = 38.36825, eval_loss = 138.99229, test_loss = 130.05003 [22.1s]
# [Epoch 49] train_loss = 37.93924, eval_loss = 37.74403, test_loss = 100.59584 [23.6s]
# /Users/alexei.ermochkine/Desktop/ma5/ML4PM/assignment_3_graded/ML4PM_assignment3/training.py:193: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=self.device))
# [Epoch 50] train_loss = 37.95901, eval_loss = 93.86123, test_loss = 311.64597 [23.2s]
# Task done in 1179s
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106134002.pt loaded to mps
# 100%|██████████| 394/394 [00:02<00:00, 177.43it/s]
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106134002.pt loaded to mps
# 100%|██████████| 451/451 [00:02<00:00, 199.32it/s]
# --------------------- BEGGINING NEW SEED: 43 ----------------
# CNN(
#   (conv_layers): Sequential(
#     (0): Conv1d(18, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (7): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=500, out_features=50, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (bn_fc): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=50, out_features=1, bias=True)
# )
# Training model for 50 epochs...
# [Epoch 1] train_loss = 140.95193, eval_loss = 496.68195, test_loss = 920.61896 [23.6s]
# [Epoch 2] train_loss = 60.39144, eval_loss = 175.53876, test_loss = 396.50140 [23.3s]
# [Epoch 3] train_loss = 54.19131, eval_loss = 127.95755, test_loss = 308.70566 [24.5s]
# [Epoch 4] train_loss = 51.04868, eval_loss = 188.92253, test_loss = 152.90836 [23.1s]
# [Epoch 5] train_loss = 49.73533, eval_loss = 480.85739, test_loss = 969.64795 [22.4s]
# [Epoch 6] train_loss = 47.77135, eval_loss = 50.19617, test_loss = 100.66441 [24.0s]
# [Epoch 7] train_loss = 47.37577, eval_loss = 65.52607, test_loss = 162.24686 [23.7s]
# [Epoch 8] train_loss = 46.54972, eval_loss = 104.03394, test_loss = 171.18224 [24.1s]
# [Epoch 9] train_loss = 46.77761, eval_loss = 38.88551, test_loss = 77.52071 [23.6s]
# [Epoch 10] train_loss = 45.36570, eval_loss = 136.96504, test_loss = 198.45622 [24.2s]
# [Epoch 11] train_loss = 45.50856, eval_loss = 112.42854, test_loss = 89.98768 [25.7s]
# [Epoch 12] train_loss = 45.25121, eval_loss = 178.87228, test_loss = 411.12680 [25.3s]
# [Epoch 13] train_loss = 44.42112, eval_loss = 38.09682, test_loss = 97.18040 [25.2s]
# [Epoch 29] train_loss = 40.94735, eval_loss = 176.68704, test_loss = 208.20279 [24.8s]
# [Epoch 30] train_loss = 40.76774, eval_loss = 263.45416, test_loss = 613.54205 [24.9s]
# [Epoch 31] train_loss = 40.58078, eval_loss = 98.89404, test_loss = 267.15204 [25.3s]
# [Epoch 32] train_loss = 40.45095, eval_loss = 143.69987, test_loss = 377.93582 [27.4s]
# [Epoch 33] train_loss = 40.16715, eval_loss = 216.62164, test_loss = 204.25157 [24.9s]
# [Epoch 34] train_loss = 39.98693, eval_loss = 80.85004, test_loss = 229.56711 [25.1s]
# [Epoch 35] train_loss = 39.79412, eval_loss = 73.81583, test_loss = 80.65191 [23.7s]
# [Epoch 36] train_loss = 39.75203, eval_loss = 95.05512, test_loss = 66.46465 [23.4s]
# [Epoch 37] train_loss = 39.57570, eval_loss = 139.16185, test_loss = 442.57697 [24.0s]
# [Epoch 38] train_loss = 39.62312, eval_loss = 195.02473, test_loss = 274.68100 [24.4s]
# [Epoch 39] train_loss = 39.57196, eval_loss = 53.59969, test_loss = 166.92165 [24.2s]
# [Epoch 40] train_loss = 39.21218, eval_loss = 49.06639, test_loss = 92.57123 [25.1s]
# [Epoch 41] train_loss = 39.04054, eval_loss = 160.19582, test_loss = 203.48488 [25.1s]
# [Epoch 42] train_loss = 39.15362, eval_loss = 87.49543, test_loss = 123.07695 [21.8s]
# [Epoch 43] train_loss = 38.90381, eval_loss = 94.75447, test_loss = 125.16492 [21.6s]
# [Epoch 44] train_loss = 38.92033, eval_loss = 49.36937, test_loss = 61.39075 [21.8s]
# [Epoch 45] train_loss = 38.62387, eval_loss = 154.35437, test_loss = 207.13513 [21.8s]
# [Epoch 46] train_loss = 38.82216, eval_loss = 49.14882, test_loss = 53.36937 [21.5s]
# [Epoch 47] train_loss = 38.49923, eval_loss = 91.52951, test_loss = 243.76968 [21.6s]
# [Epoch 48] train_loss = 38.73465, eval_loss = 73.82181, test_loss = 196.31813 [22.0s]
# [Epoch 49] train_loss = 38.31657, eval_loss = 64.08978, test_loss = 208.49030 [23.9s]
# [Epoch 50] train_loss = 38.10653, eval_loss = 164.60768, test_loss = 168.01253 [25.0s]
# Task done in 1226s
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106144638.pt loaded to mps
# 100%|██████████| 394/394 [00:02<00:00, 154.49it/s]
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106144638.pt loaded to mps
# 100%|██████████| 451/451 [00:02<00:00, 182.29it/s]
# --------------------- BEGGINING NEW SEED: 46 ----------------
# CNN(
#   (conv_layers): Sequential(
#     (0): Conv1d(18, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv1d(10, 10, kernel_size=(10,), stride=(1,), padding=same)
#     (7): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=500, out_features=50, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (bn_fc): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   
# [Epoch 32] train_loss = 40.49897, eval_loss = 74.69732, test_loss = 105.86881 [24.7s]
# [Epoch 33] train_loss = 40.49038, eval_loss = 57.88385, test_loss = 195.21945 [24.8s]
# [Epoch 34] train_loss = 40.27037, eval_loss = 123.29267, test_loss = 75.27846 [27.6s]
# [Epoch 35] train_loss = 40.03660, eval_loss = 51.24227, test_loss = 171.78076 [26.7s]
# [Epoch 36] train_loss = 39.91994, eval_loss = 103.21625, test_loss = 281.91287 [25.3s]
# [Epoch 37] train_loss = 40.02879, eval_loss = 148.97910, test_loss = 163.16245 [25.4s]
# [Epoch 38] train_loss = 39.72124, eval_loss = 100.59896, test_loss = 134.42583 [25.6s]
# [Epoch 39] train_loss = 39.64157, eval_loss = 134.63901, test_loss = 121.98782 [24.8s]
# [Epoch 40] train_loss = 39.74453, eval_loss = 111.34367, test_loss = 181.89378 [24.7s]
# [Epoch 41] train_loss = 39.56455, eval_loss = 68.33823, test_loss = 61.58964 [24.3s]
# [Epoch 42] train_loss = 39.53038, eval_loss = 36.70716, test_loss = 103.54252 [24.6s]
# [Epoch 43] train_loss = 39.28450, eval_loss = 134.53371, test_loss = 349.79578 [24.8s]
# [Epoch 44] train_loss = 39.06870, eval_loss = 49.53951, test_loss = 79.45276 [24.6s]
# [Epoch 45] train_loss = 39.59116, eval_loss = 98.91397, test_loss = 120.18699 [28.0s]
# [Epoch 46] train_loss = 39.04423, eval_loss = 51.03185, test_loss = 117.41844 [25.3s]
# [Epoch 47] train_loss = 38.99420, eval_loss = 35.26630, test_loss = 86.66695 [24.8s]
# [Epoch 48] train_loss = 39.11266, eval_loss = 89.26004, test_loss = 227.89401 [27.1s]
# [Epoch 49] train_loss = 38.97029, eval_loss = 207.05099, test_loss = 210.95149 [27.4s]
# [Epoch 50] train_loss = 38.82048, eval_loss = 71.68575, test_loss = 99.33806 [25.1s]
# Task done in 1273s
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106150710.pt loaded to mps
# 100%|██████████| 394/394 [00:02<00:00, 160.72it/s]
# Evaluating test RUL...
# Model CNN saved in models_batchnormdropout/batchnormdropout_1106150710.pt loaded to mps
# 100%|██████████| 451/451 [00:02<00:00, 194.68it/s]

# %% [markdown]
# # PLOTTING RESULTS

# %%
plot_test_rul_predictions(all_df_test, df_all, model_name, save=True, show=True)

# %%
# Plot the aggregated losses
plot_aggregated_losses(all_train_losses, all_eval_losses, all_test_losses, model_name, save=True, show=True)

# %%
df_all.to_csv(f'test_scores/{model_name}_df_all.csv', index=False)
df_all.head()
# Out:
#       score      rmse  seed
# 0  2.213326  7.061282    42
# 1  2.408841  7.777603    43
# 2  2.408758  7.753370    44
# 3  2.277544  7.399192    45
# 4  2.084281  6.720714    46

# %%
results_df, best_idx = evaluate_per_unit_stored(df_all, all_df_test)
# Out:
# Per-unit performance metrics:
# ================================================================================
#   Unit     Type         RMSE   NASA Score      Samples
# --------------------------------------------------------------------------------
#     11     Test        8.095        1.386        63400
#     14     Test        6.959        0.193        11877
#     15     Test        3.455        0.506        39997
#    Avg  Summary        6.169        2.084       115274
# ================================================================================
